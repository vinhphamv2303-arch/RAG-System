# %%
from google import genai

client = genai.Client(api_key="AIzaSyDj5MNXnqduUrnjj3xDyrQWUVASIK7OnT0")

response = client.models.generate_content(
    model="gemini-1.5-flash-latest",
    contents="Giải thích RAG là gì?"
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[4], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key="AIzaSyDj5MNXnqduUrnjj3xDyrQWUVASIK7OnT0")
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-1.5-flash-latest",
#       7     contents="Giải thích RAG là gì?"
#       8 )
#      10 print(response.text)
#
# File ~/miniconda3/envs/thesis/lib/python3.10/site-packages/google/genai/models.py:5644, in Models.generate_content(self, model, contents, config)
#    5642 while remaining_remote_calls_afc > 0:
#    5643   i += 1
# -> 5644   response = self._generate_content(
#    5645       model=model, contents=contents, config=parsed_config
#    5646   )
#    5648   function_map = _extra_utils.get_function_map(parsed_config)
#    5649   if not function_map:
#
# ...
